# %%
from  datetime import *
import pandas as pd
data_execucao = datetime.today() - pd.Timedelta(hours=3)
data_execucao = datetime.strftime(data_execucao, "%d/%m/%Y ás %H:%M:%S")
print(data_execucao)
# Out:
# 14/12/2022 ás 15:20:22
